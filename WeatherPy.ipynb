# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# API Query
url = "http://api.openweathermap.org/data/2.5/weather?"
units="metric"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Output File (CSV)
output_data_file = "cities.csv"

# Exporting list of cities to csv file
with open (output_data_file, "w", newline='') as cities_file:
    city_data=csv.writer(cities_file, delimiter=",")
    for city in cities:
        city_data.writerow(city)

# %%
url= "https://api.openweathermap.org/data/2.5/weather?"
units="metric"

for city in cities:
    query_url = f"{url}appid={api_key}&units={units}&q={city}"

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    try:
        response = requests.get(f"{url}appid={api_key}&units={units}&q={city}").json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Atuona
# http://api.openweathermap.org/data/2.5/weather?&q=atuona
# Processing Record 2 | Busselton
# http://api.openweathermap.org/data/2.5/weather?&q=busselton
# Processing Record 3 | Bulgan
# http://api.openweathermap.org/data/2.5/weather?&q=bulgan
# Processing Record 4 | Faanui
# http://api.openweathermap.org/data/2.5/weather?&q=faanui
# Processing Record 5 | Gamba
# http://api.openweathermap.org/data/2.5/weather?&q=gamba
# Processing Record 6 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&q=tasiilaq
# Processing Record 7 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?&q=katsuura
# Processing Record 8 | Bluff
# http://api.openweathermap.org/data/2.5/weather?&q=bluff
# Processing Record 9 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?&q=fairbanks
# Processing Record 10 | Macusani
# http://api.openweathermap.org/data/2.5/weather?&q=macusani
# Processing Record 11 | Sao Paulo de Olivenca
# http://api.openweathermap.org/data/2.5/weather?&q=sao paulo de olivenca
# City not found. Skipping...
# Processing Record 12 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?&q=luderitz
# Processing Record 13 | Lebu
# http://api.openweathermap.org/data/2.5/weather?&q=lebu
# Processing Record 14 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?&q=cherskiy
# Processing Record 15 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?&q=paamiut
# Processing Record 16 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?&q=mahebourg
# Processing Record 17 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?&q=port alfred
# Processing Record 18 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?&q=tessalit
# Processing Record 19 | Fare
# http://api.openweathermap.org/data/2.5/weather?&q=fare
# Processing Record 20 | Innisfail
# http://api.openweathermap.org/data/2.5/weather?&q=innisfail
# City not found. Skipping...
# Processing Record 21 | Jalingo
# http://api.openweathermap.org/data/2.5/weather?&q=jalingo
# Processing Record 22 | Hilo
# http://api.openweathermap.org/data/2.5/weather?&q=hilo
# Processing Record 23 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?&q=kaitangata
# Processing Record 24 | Namibe
# http://api.openweathermap.org/data/2.5/weather?&q=namibe
# Processing Record 25 | Airai
# http://api.openweathermap.org/data/2.5/weather?&q=airai
# Processing Record 26 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?&q=umm lajj
# Processing Record 27 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?&q=lompoc
# Processing Record 28 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&q=tuktoyaktuk
# Processing Record 29 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?&q=bubaque
# Processing Record 30 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?&q=grand gaube
# Processing Record 31 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?&q=rikitea
# Processing Record 32 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?&q=ponta do sol
# Processing Record 33 | Gizo
# http://api.openweathermap.org/data/2.5/weather?&q=gizo
# Processing Record 34 | Netivot
# http://api.openweathermap.org/data/2.5/weather?&q=netivot
# Processing Record 35 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?&q=puerto ayora
# Processing Record 36 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?&q=kavieng
# Processing Record 37 | Yanliang
# http://api.openweathermap.org/data/2.5/weather?&q=yanliang
# Processing Record 38 | Solrod
# http://api.openweathermap.org/data/2.5/weather?&q=solrod
# Processing Record 39 | Vardo
# http://api.openweathermap.org/data/2.5/weather?&q=vardo
# Processing Record 40 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?&q=provideniya
# Processing Record 41 | Nadym
# http://api.openweathermap.org/data/2.5/weather?&q=nadym
# Processing Record 42 | Ushtobe
# http://api.openweathermap.org/data/2.5/weather?&q=ushtobe
# Processing Record 43 | Ahuimanu
# http://api.openweathermap.org/data/2.5/weather?&q=ahuimanu
# Processing Record 44 | Portland
# http://api.openweathermap.org/data/2.5/weather?&q=portland
# Processing Record 45 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?&q=punta arenas
# Processing Record 46 | Caiaponia
# http://api.openweathermap.org/data/2.5/weather?&q=caiaponia
# City not found. Skipping...
# Processing Record 47 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&q=vestmannaeyjar
# Processing Record 48 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?&q=cape town
# Processing Record 49 | Agirish
# http://api.openweathermap.org/data/2.5/weather?&q=agirish
# Processing Record 50 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?&q=ushuaia
# Processing Record 51 | Jonesboro
# http://api.openweathermap.org/data/2.5/weather?&q=jonesboro
# Processing Record 52 | Novobelokatay
# http://api.openweathermap.org/data/2.5/weather?&q=novobelokatay
# Processing Record 53 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?&q=kimbe
# Processing Record 54 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?&q=arraial do cabo
# Processing Record 55 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&q=bredasdorp
# Processing Record 56 | Terney
# http://api.openweathermap.org/data/2.5/weather?&q=terney
# Processing Record 57 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?&q=port hedland
# City not found. Skipping...
# Processing Record 58 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?&q=saldanha
# Processing Record 59 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?&q=walvis bay
# Processing Record 60 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?&q=butaritari
# Processing Record 61 | Ivanteyevka
# http://api.openweathermap.org/data/2.5/weather?&q=ivanteyevka
# Processing Record 62 | Barrow
# http://api.openweathermap.org/data/2.5/weather?&q=barrow
# Processing Record 63 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&q=nikolskoye
# Processing Record 64 | Mataura
# http://api.openweathermap.org/data/2.5/weather?&q=mataura
# Processing Record 65 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?&q=praia da vitoria
# Processing Record 66 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?&q=qaanaaq
# Processing Record 67 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?&q=upernavik
# Processing Record 68 | Perth
# http://api.openweathermap.org/data/2.5/weather?&q=perth
# Processing Record 69 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?&q=khatanga
# Processing Record 70 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?&q=port elizabeth
# Processing Record 71 | Mwense
# http://api.openweathermap.org/data/2.5/weather?&q=mwense
# Processing Record 72 | Ruzomberok
# http://api.openweathermap.org/data/2.5/weather?&q=ruzomberok
# Processing Record 73 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?&q=ahipara
# Processing Record 74 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?&q=manokwari
# Processing Record 75 | Rawson
# http://api.openweathermap.org/data/2.5/weather?&q=rawson
# Processing Record 76 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?&q=kapaa
# Processing Record 77 | Valdivia
# http://api.openweathermap.org/data/2.5/weather?&q=valdivia
# City not found. Skipping...
# Processing Record 78 | Louis Trichardt
# http://api.openweathermap.org/data/2.5/weather?&q=louis trichardt
# Processing Record 79 | Saint George
# http://api.openweathermap.org/data/2.5/weather?&q=saint george
# Processing Record 80 | Olinda
# http://api.openweathermap.org/data/2.5/weather?&q=olinda
# Processing Record 81 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?&q=saint-philippe
# Processing Record 82 | Avarua
# http://api.openweathermap.org/data/2.5/weather?&q=avarua
# Processing Record 83 | Izhma
# http://api.openweathermap.org/data/2.5/weather?&q=izhma
# Processing Record 84 | Souillac
# http://api.openweathermap.org/data/2.5/weather?&q=souillac
# Processing Record 85 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?&q=nanortalik
# Processing Record 86 | Gospic
# http://api.openweathermap.org/data/2.5/weather?&q=gospic
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 87 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?&q=port hardy
# Processing Record 88 | Perelyub
# http://api.openweathermap.org/data/2.5/weather?&q=perelyub
# Processing Record 89 | Manono
# http://api.openweathermap.org/data/2.5/weather?&q=manono
# Processing Record 90 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?&q=port blair
# Processing Record 91 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?&q=new norfolk
# Processing Record 92 | Castro
# http://api.openweathermap.org/data/2.5/weather?&q=castro
# Processing Record 93 | Dikson
# http://api.openweathermap.org/data/2.5/weather?&q=dikson
# City not found. Skipping...
# Processing Record 94 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?&q=kamenka
# Processing Record 95 | Biak
# http://api.openweathermap.org/data/2.5/weather?&q=biak
# Processing Record 96 | Kato Mazarakion
# http://api.openweathermap.org/data/2.5/weather?&q=kato mazarakion
# Processing Record 97 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&q=pangnirtung
# Processing Record 98 | Polunochnoye
# http://api.openweathermap.org/data/2.5/weather?&q=polunochnoye
# Processing Record 99 | Karasjok
# http://api.openweathermap.org/data/2.5/weather?&q=karasjok
# Processing Record 100 | Indi
# http://api.openweathermap.org/data/2.5/weather?&q=indi
# Processing Record 101 | Isangel
# http://api.openweathermap.org/data/2.5/weather?&q=isangel
# Processing Record 102 | Billings
# http://api.openweathermap.org/data/2.5/weather?&q=billings
# Processing Record 103 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?&q=bambous virieux
# Processing Record 104 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?&q=saint-augustin
# City not found. Skipping...
# Processing Record 105 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?&q=santa maria
# Processing Record 106 | Lahaina
# http://api.openweathermap.org/data/2.5/weather?&q=lahaina
# Processing Record 107 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?&q=berlevag
# Processing Record 108 | Lafia
# http://api.openweathermap.org/data/2.5/weather?&q=lafia
# Processing Record 109 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?&q=ribeira grande
# Processing Record 110 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?&q=cayenne
# Processing Record 111 | Binzhou
# http://api.openweathermap.org/data/2.5/weather?&q=binzhou
# Processing Record 112 | San Juan de Uraba
# http://api.openweathermap.org/data/2.5/weather?&q=san juan de uraba
# City not found. Skipping...
# Processing Record 113 | College
# http://api.openweathermap.org/data/2.5/weather?&q=college
# Processing Record 114 | Viedma
# http://api.openweathermap.org/data/2.5/weather?&q=viedma
# Processing Record 115 | Atar
# http://api.openweathermap.org/data/2.5/weather?&q=atar
# Processing Record 116 | Moussoro
# http://api.openweathermap.org/data/2.5/weather?&q=moussoro
# Processing Record 117 | Wanaka
# http://api.openweathermap.org/data/2.5/weather?&q=wanaka
# Processing Record 118 | Onega
# http://api.openweathermap.org/data/2.5/weather?&q=onega
# Processing Record 119 | Mackay
# http://api.openweathermap.org/data/2.5/weather?&q=mackay
# Processing Record 120 | Hobart
# http://api.openweathermap.org/data/2.5/weather?&q=hobart
# Processing Record 121 | Moa
# http://api.openweathermap.org/data/2.5/weather?&q=moa
# Processing Record 122 | Ilhabela
# http://api.openweathermap.org/data/2.5/weather?&q=ilhabela
# Processing Record 123 | Khani
# http://api.openweathermap.org/data/2.5/weather?&q=khani
# City not found. Skipping...
# Processing Record 124 | Pevek
# http://api.openweathermap.org/data/2.5/weather?&q=pevek
# Processing Record 125 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=hithadhoo
# Processing Record 126 | Darlowo
# http://api.openweathermap.org/data/2.5/weather?&q=darlowo
# Processing Record 127 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?&q=turukhansk
# Processing Record 128 | Santa Quiteria
# http://api.openweathermap.org/data/2.5/weather?&q=santa quiteria
# Processing Record 129 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?&q=alice springs
# Processing Record 130 | Albany
# http://api.openweathermap.org/data/2.5/weather?&q=albany
# Processing Record 131 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?&q=dunedin
# Processing Record 132 | Bastrop
# http://api.openweathermap.org/data/2.5/weather?&q=bastrop
# City not found. Skipping...
# Processing Record 133 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?&q=bathsheba
# Processing Record 134 | Turochak
# http://api.openweathermap.org/data/2.5/weather?&q=turochak
# City not found. Skipping...
# Processing Record 135 | Husavik
# http://api.openweathermap.org/data/2.5/weather?&q=husavik
# City not found. Skipping...
# Processing Record 136 | Mayo
# http://api.openweathermap.org/data/2.5/weather?&q=mayo
# Processing Record 137 | Pisco
# http://api.openweathermap.org/data/2.5/weather?&q=pisco
# Processing Record 138 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?&q=carnarvon
# Processing Record 139 | Thompson
# http://api.openweathermap.org/data/2.5/weather?&q=thompson
# Processing Record 140 | Cam Ranh
# http://api.openweathermap.org/data/2.5/weather?&q=cam ranh
# Processing Record 141 | Venice
# http://api.openweathermap.org/data/2.5/weather?&q=venice
# Processing Record 142 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?&q=nemuro
# Processing Record 143 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?&q=nelson bay
# Processing Record 144 | Beroroha
# http://api.openweathermap.org/data/2.5/weather?&q=beroroha
# Processing Record 145 | Manaus
# http://api.openweathermap.org/data/2.5/weather?&q=manaus
# Processing Record 146 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?&q=hamilton
# Processing Record 147 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?&q=cabo san lucas
# Processing Record 148 | Farah
# http://api.openweathermap.org/data/2.5/weather?&q=farah
# Processing Record 149 | Santa Fe
# http://api.openweathermap.org/data/2.5/weather?&q=santa fe
# Processing Record 150 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?&q=talcahuano
# City not found. Skipping...
# Processing Record 151 | Rach Gia
# http://api.openweathermap.org/data/2.5/weather?&q=rach gia
# Processing Record 152 | East London
# http://api.openweathermap.org/data/2.5/weather?&q=east london
# Processing Record 153 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?&q=sinnamary
# Processing Record 154 | Vaini
# http://api.openweathermap.org/data/2.5/weather?&q=vaini
# Processing Record 155 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?&q=beyneu
# Processing Record 156 | Taltal
# http://api.openweathermap.org/data/2.5/weather?&q=taltal
# Processing Record 157 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?&q=hermanus
# Processing Record 158 | Kahului
# http://api.openweathermap.org/data/2.5/weather?&q=kahului
# Processing Record 159 | Sitka
# http://api.openweathermap.org/data/2.5/weather?&q=sitka
# Processing Record 160 | Sorong
# http://api.openweathermap.org/data/2.5/weather?&q=sorong
# Processing Record 161 | Bethel
# http://api.openweathermap.org/data/2.5/weather?&q=bethel
# Processing Record 162 | Nkawkaw
# http://api.openweathermap.org/data/2.5/weather?&q=nkawkaw
# Processing Record 163 | Ladario
# http://api.openweathermap.org/data/2.5/weather?&q=ladario
# Processing Record 164 | Wajima
# http://api.openweathermap.org/data/2.5/weather?&q=wajima
# Processing Record 165 | Karratha
# http://api.openweathermap.org/data/2.5/weather?&q=karratha
# Processing Record 166 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?&q=inhambane
# City not found. Skipping...
# Processing Record 167 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?&q=waingapu
# City not found. Skipping...
# Processing Record 168 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?&q=georgetown
# Processing Record 169 | Lasa
# http://api.openweathermap.org/data/2.5/weather?&q=lasa
# City not found. Skipping...
# Processing Record 170 | Medicine Hat
# http://api.openweathermap.org/data/2.5/weather?&q=medicine hat
# Processing Record 171 | Yilan
# http://api.openweathermap.org/data/2.5/weather?&q=yilan
# Processing Record 172 | Mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?&q=mnogovershinnyy
# Processing Record 173 | Northam
# http://api.openweathermap.org/data/2.5/weather?&q=northam
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 174 | Namie
# http://api.openweathermap.org/data/2.5/weather?&q=namie
# Processing Record 175 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=mahibadhoo
# Processing Record 176 | Chuy
# http://api.openweathermap.org/data/2.5/weather?&q=chuy
# Processing Record 177 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?&q=belmonte
# Processing Record 178 | Lac du Bonnet
# http://api.openweathermap.org/data/2.5/weather?&q=lac du bonnet
# Processing Record 179 | Faya
# http://api.openweathermap.org/data/2.5/weather?&q=faya
# Processing Record 180 | Yurimaguas
# http://api.openweathermap.org/data/2.5/weather?&q=yurimaguas
# Processing Record 181 | Redmond
# http://api.openweathermap.org/data/2.5/weather?&q=redmond
# Processing Record 182 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?&q=geraldton
# Processing Record 183 | Lermontovka
# http://api.openweathermap.org/data/2.5/weather?&q=lermontovka
# Processing Record 184 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?&q=kruisfontein
# Processing Record 185 | Murgab
# http://api.openweathermap.org/data/2.5/weather?&q=murgab
# Processing Record 186 | Rocha
# http://api.openweathermap.org/data/2.5/weather?&q=rocha
# Processing Record 187 | Bafq
# http://api.openweathermap.org/data/2.5/weather?&q=bafq
# Processing Record 188 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?&q=sioux lookout
# Processing Record 189 | Centralia
# http://api.openweathermap.org/data/2.5/weather?&q=centralia
# Processing Record 190 | Victoria
# http://api.openweathermap.org/data/2.5/weather?&q=victoria
# Processing Record 191 | Sahuaripa
# http://api.openweathermap.org/data/2.5/weather?&q=sahuaripa
# Processing Record 192 | Kaputa
# http://api.openweathermap.org/data/2.5/weather?&q=kaputa
# Processing Record 193 | Poya
# http://api.openweathermap.org/data/2.5/weather?&q=poya
# Processing Record 194 | Jasper
# http://api.openweathermap.org/data/2.5/weather?&q=jasper
# Processing Record 195 | Aberdeen
# http://api.openweathermap.org/data/2.5/weather?&q=aberdeen
# Processing Record 196 | Veraval
# http://api.openweathermap.org/data/2.5/weather?&q=veraval
# Processing Record 197 | Anloga
# http://api.openweathermap.org/data/2.5/weather?&q=anloga
# Processing Record 198 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?&q=zhezkazgan
# City not found. Skipping...
# Processing Record 199 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?&q=chokurdakh
# Processing Record 200 | Lahat
# http://api.openweathermap.org/data/2.5/weather?&q=lahat
# Processing Record 201 | Adelaide
# http://api.openweathermap.org/data/2.5/weather?&q=adelaide
# Processing Record 202 | Sunrise Manor
# http://api.openweathermap.org/data/2.5/weather?&q=sunrise manor
# Processing Record 203 | Soe
# http://api.openweathermap.org/data/2.5/weather?&q=soe
# Processing Record 204 | Goure
# http://api.openweathermap.org/data/2.5/weather?&q=goure
# Processing Record 205 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?&q=san patricio
# Processing Record 206 | Arlit
# http://api.openweathermap.org/data/2.5/weather?&q=arlit
# Processing Record 207 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?&q=sao filipe
# Processing Record 208 | Hakkari
# http://api.openweathermap.org/data/2.5/weather?&q=hakkari
# Processing Record 209 | Franklin Park
# http://api.openweathermap.org/data/2.5/weather?&q=franklin park
# Processing Record 210 | Salazie
# http://api.openweathermap.org/data/2.5/weather?&q=salazie
# Processing Record 211 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?&q=clyde river
# Processing Record 212 | Padang
# http://api.openweathermap.org/data/2.5/weather?&q=padang
# Processing Record 213 | La Libertad
# http://api.openweathermap.org/data/2.5/weather?&q=la libertad
# Processing Record 214 | Osypenko
# http://api.openweathermap.org/data/2.5/weather?&q=osypenko
# Processing Record 215 | Sevlievo
# http://api.openweathermap.org/data/2.5/weather?&q=sevlievo
# Processing Record 216 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?&q=cidreira
# Processing Record 217 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?&q=rio gallegos
# Processing Record 218 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&q=longyearbyen
# Processing Record 219 | Kyshtovka
# http://api.openweathermap.org/data/2.5/weather?&q=kyshtovka
# City not found. Skipping...
# Processing Record 220 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?&q=boa vista
# Processing Record 221 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?&q=coquimbo
# Processing Record 222 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?&q=saskylakh
# Processing Record 223 | Nisia Floresta
# http://api.openweathermap.org/data/2.5/weather?&q=nisia floresta
# Processing Record 224 | Ust-Koksa
# http://api.openweathermap.org/data/2.5/weather?&q=ust-koksa
# Processing Record 225 | Chingirlau
# http://api.openweathermap.org/data/2.5/weather?&q=chingirlau
# Processing Record 226 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?&q=yar-sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 227 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?&q=severo-kurilsk
# Processing Record 228 | Broome
# http://api.openweathermap.org/data/2.5/weather?&q=broome
# Processing Record 229 | Tabou
# http://api.openweathermap.org/data/2.5/weather?&q=tabou
# Processing Record 230 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?&q=te anau
# Processing Record 231 | Marrakesh
# http://api.openweathermap.org/data/2.5/weather?&q=marrakesh
# Processing Record 232 | Destin
# http://api.openweathermap.org/data/2.5/weather?&q=destin
# Processing Record 233 | Phangnga
# http://api.openweathermap.org/data/2.5/weather?&q=phangnga
# Processing Record 234 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?&q=constitucion
# Processing Record 235 | Tuy Hoa
# http://api.openweathermap.org/data/2.5/weather?&q=tuy hoa
# City not found. Skipping...
# Processing Record 236 | Lugus
# http://api.openweathermap.org/data/2.5/weather?&q=lugus
# Processing Record 237 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?&q=aklavik
# Processing Record 238 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?&q=jamestown
# Processing Record 239 | Ibb
# http://api.openweathermap.org/data/2.5/weather?&q=ibb
# Processing Record 240 | Esperance
# http://api.openweathermap.org/data/2.5/weather?&q=esperance
# Processing Record 241 | Semey
# http://api.openweathermap.org/data/2.5/weather?&q=semey
# Processing Record 242 | Manaure
# http://api.openweathermap.org/data/2.5/weather?&q=manaure
# Processing Record 243 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?&q=rio grande
# Processing Record 244 | Hermosillo
# http://api.openweathermap.org/data/2.5/weather?&q=hermosillo
# City not found. Skipping...
# Processing Record 245 | Bayonet Point
# http://api.openweathermap.org/data/2.5/weather?&q=bayonet point
# Processing Record 246 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=saint-pierre
# Processing Record 247 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?&q=bonavista
# Processing Record 248 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?&q=bay roberts
# Processing Record 249 | Torbay
# http://api.openweathermap.org/data/2.5/weather?&q=torbay
# Processing Record 250 | Pangai
# http://api.openweathermap.org/data/2.5/weather?&q=pangai
# Processing Record 251 | Koumac
# http://api.openweathermap.org/data/2.5/weather?&q=koumac
# Processing Record 252 | Svetlaya
# http://api.openweathermap.org/data/2.5/weather?&q=svetlaya
# Processing Record 253 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?&q=ilulissat
# City not found. Skipping...
# Processing Record 254 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?&q=la ronge
# Processing Record 255 | Hay River
# http://api.openweathermap.org/data/2.5/weather?&q=hay river
# Processing Record 256 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?&q=lorengau
# Processing Record 257 | Traverse City
# http://api.openweathermap.org/data/2.5/weather?&q=traverse city
# Processing Record 258 | Kalianget
# http://api.openweathermap.org/data/2.5/weather?&q=kalianget
# City not found. Skipping...
# Processing Record 259 | Vao
# http://api.openweathermap.org/data/2.5/weather?&q=vao
# Processing Record 260 | Hammerfest
# http://api.openweathermap.org/data/2.5/weather?&q=hammerfest
# Processing Record 261 | Americus
# http://api.openweathermap.org/data/2.5/weather?&q=americus
# Processing Record 262 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?&q=kodiak
# Processing Record 263 | Port Saint John
# http://api.openweathermap.org/data/2.5/weather?&q=port saint john
# Processing Record 264 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?&q=vila velha
# City not found. Skipping...
# Processing Record 265 | Rumuruti
# http://api.openweathermap.org/data/2.5/weather?&q=rumuruti
# Processing Record 266 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?&q=okhotsk
# City not found. Skipping...
# Processing Record 267 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?&q=port augusta
# Processing Record 268 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?&q=half moon bay
# Processing Record 269 | Matagami
# http://api.openweathermap.org/data/2.5/weather?&q=matagami
# Processing Record 270 | Alofi
# http://api.openweathermap.org/data/2.5/weather?&q=alofi
# Processing Record 271 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?&q=kloulklubed
# Processing Record 272 | Monywa
# http://api.openweathermap.org/data/2.5/weather?&q=monywa
# Processing Record 273 | Puebloviejo
# http://api.openweathermap.org/data/2.5/weather?&q=puebloviejo
# City not found. Skipping...
# Processing Record 274 | Watsa
# http://api.openweathermap.org/data/2.5/weather?&q=watsa
# Processing Record 275 | Le Vauclin
# http://api.openweathermap.org/data/2.5/weather?&q=le vauclin
# Processing Record 276 | Clarence Town
# http://api.openweathermap.org/data/2.5/weather?&q=clarence town
# Processing Record 277 | Balasore
# http://api.openweathermap.org/data/2.5/weather?&q=baleshwar
# Processing Record 278 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?&q=antofagasta
# Processing Record 279 | Mtwara
# http://api.openweathermap.org/data/2.5/weather?&q=mtwara
# Processing Record 280 | Burlington
# http://api.openweathermap.org/data/2.5/weather?&q=burlington
# Processing Record 281 | Talaya
# http://api.openweathermap.org/data/2.5/weather?&q=talaya
# Processing Record 282 | Kamyshevatskaya
# http://api.openweathermap.org/data/2.5/weather?&q=kamyshevatskaya
# Processing Record 283 | Villa Bruzual
# http://api.openweathermap.org/data/2.5/weather?&q=villa bruzual
# Processing Record 284 | Palana
# http://api.openweathermap.org/data/2.5/weather?&q=palana
# Processing Record 285 | Powell River
# http://api.openweathermap.org/data/2.5/weather?&q=powell river
# Processing Record 286 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?&q=oussouye
# Processing Record 287 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?&q=hasaki
# Processing Record 288 | Zabid
# http://api.openweathermap.org/data/2.5/weather?&q=zabid
# Processing Record 289 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?&q=kununurra
# Processing Record 290 | Sigiriya
# http://api.openweathermap.org/data/2.5/weather?&q=sigiriya
# Processing Record 291 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?&q=sao joao da barra
# Processing Record 292 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?&q=fortuna
# Processing Record 293 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?&q=iqaluit
# Processing Record 294 | Shwebo
# http://api.openweathermap.org/data/2.5/weather?&q=shwebo
# Processing Record 295 | Tiruttani
# http://api.openweathermap.org/data/2.5/weather?&q=tiruttani
# Processing Record 296 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?&q=vila franca do campo
# Processing Record 297 | Poso
# http://api.openweathermap.org/data/2.5/weather?&q=poso
# Processing Record 298 | Trinidad
# http://api.openweathermap.org/data/2.5/weather?&q=trinidad
# Processing Record 299 | Bijie
# http://api.openweathermap.org/data/2.5/weather?&q=bijie
# Processing Record 300 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?&q=yellowknife
# Processing Record 301 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?&q=ambilobe
# City not found. Skipping...
# Processing Record 302 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?&q=vestmanna
# Processing Record 303 | Verkh-Usugli
# http://api.openweathermap.org/data/2.5/weather?&q=verkh-usugli
# Processing Record 304 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?&q=tiksi
# Processing Record 305 | Avera
# http://api.openweathermap.org/data/2.5/weather?&q=avera
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 306 | Kralendijk
# http://api.openweathermap.org/data/2.5/weather?&q=kralendijk
# Processing Record 307 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?&q=coihaique
# Processing Record 308 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?&q=ostrovnoy
# Processing Record 309 | La Palma
# http://api.openweathermap.org/data/2.5/weather?&q=la palma
# City not found. Skipping...
# Processing Record 310 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?&q=mar del plata
# Processing Record 311 | Amarante do Maranhao
# http://api.openweathermap.org/data/2.5/weather?&q=amarante do maranhao
# City not found. Skipping...
# Processing Record 312 | Vilyuysk
# http://api.openweathermap.org/data/2.5/weather?&q=vilyuysk
# City not found. Skipping...
# Processing Record 313 | Seoul
# http://api.openweathermap.org/data/2.5/weather?&q=seoul
# Processing Record 314 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?&q=ixtapa
# Processing Record 315 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?&q=meulaboh
# Processing Record 316 | Atherton
# http://api.openweathermap.org/data/2.5/weather?&q=atherton
# Processing Record 317 | Mayumba
# http://api.openweathermap.org/data/2.5/weather?&q=mayumba
# Processing Record 318 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?&q=narsaq
# City not found. Skipping...
# Processing Record 319 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?&q=shimoda
# Processing Record 320 | Burns Lake
# http://api.openweathermap.org/data/2.5/weather?&q=burns lake
# Processing Record 321 | Poum
# http://api.openweathermap.org/data/2.5/weather?&q=poum
# Processing Record 322 | Putina
# http://api.openweathermap.org/data/2.5/weather?&q=putina
# City not found. Skipping...
# Processing Record 323 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?&q=mehamn
# Processing Record 324 | Roald
# http://api.openweathermap.org/data/2.5/weather?&q=roald
# Processing Record 325 | Jawhar
# http://api.openweathermap.org/data/2.5/weather?&q=jawhar
# Processing Record 326 | Noumea
# http://api.openweathermap.org/data/2.5/weather?&q=noumea
# Processing Record 327 | Finschhafen
# http://api.openweathermap.org/data/2.5/weather?&q=finschhafen
# Processing Record 328 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?&q=acapulco
# Processing Record 329 | Lata
# http://api.openweathermap.org/data/2.5/weather?&q=lata
# Processing Record 330 | Bangolo
# http://api.openweathermap.org/data/2.5/weather?&q=bangolo
# Processing Record 331 | Tara
# http://api.openweathermap.org/data/2.5/weather?&q=tara
# Processing Record 332 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?&q=pacific grove
# Processing Record 333 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?&q=los llanos de aridane
# Processing Record 334 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?&q=haines junction
# Processing Record 335 | Maceio
# http://api.openweathermap.org/data/2.5/weather?&q=maceio
# City not found. Skipping...
# Processing Record 336 | Santa Cecilia
# http://api.openweathermap.org/data/2.5/weather?&q=santa cecilia
# Processing Record 337 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?&q=raudeberg
# Processing Record 338 | Saint-Jovite
# http://api.openweathermap.org/data/2.5/weather?&q=saint-jovite
# Processing Record 339 | Dingle
# http://api.openweathermap.org/data/2.5/weather?&q=dingle
# Processing Record 340 | Garmsar
# http://api.openweathermap.org/data/2.5/weather?&q=garmsar
# Processing Record 341 | Acajutla
# http://api.openweathermap.org/data/2.5/weather?&q=acajutla
# Processing Record 342 | Ybycui
# http://api.openweathermap.org/data/2.5/weather?&q=ybycui
# Processing Record 343 | Druzhba
# http://api.openweathermap.org/data/2.5/weather?&q=druzhba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 344 | Iroquois Falls
# http://api.openweathermap.org/data/2.5/weather?&q=iroquois falls
# Processing Record 345 | Batagay-Alyta
# http://api.openweathermap.org/data/2.5/weather?&q=batagay-alyta
# Processing Record 346 | Dong Hoi
# http://api.openweathermap.org/data/2.5/weather?&q=dong hoi
# City not found. Skipping...
# Processing Record 347 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?&q=caravelas
# Processing Record 348 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?&q=tuatapere
# Processing Record 349 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?&q=nouadhibou
# City not found. Skipping...
# Processing Record 350 | Popondetta
# http://api.openweathermap.org/data/2.5/weather?&q=popondetta
# Processing Record 351 | Tubuala
# http://api.openweathermap.org/data/2.5/weather?&q=tubuala
# Processing Record 352 | Bull Savanna
# http://api.openweathermap.org/data/2.5/weather?&q=bull savanna
# Processing Record 353 | Payo
# http://api.openweathermap.org/data/2.5/weather?&q=payo
# Processing Record 354 | Tvoroyri
# http://api.openweathermap.org/data/2.5/weather?&q=tvoroyri
# Processing Record 355 | Bela Vista do Paraiso
# http://api.openweathermap.org/data/2.5/weather?&q=bela vista do paraiso
# Processing Record 356 | Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?&q=port hawkesbury
# Processing Record 357 | Ambulu
# http://api.openweathermap.org/data/2.5/weather?&q=ambulu
# Processing Record 358 | Hofn
# http://api.openweathermap.org/data/2.5/weather?&q=hofn
# Processing Record 359 | Nome
# http://api.openweathermap.org/data/2.5/weather?&q=nome
# Processing Record 360 | Invermere
# http://api.openweathermap.org/data/2.5/weather?&q=invermere
# Processing Record 361 | Bridgend
# http://api.openweathermap.org/data/2.5/weather?&q=bridgend
# Processing Record 362 | Laukaa
# http://api.openweathermap.org/data/2.5/weather?&q=laukaa
# Processing Record 363 | Jay
# http://api.openweathermap.org/data/2.5/weather?&q=jay
# Processing Record 364 | Camacha
# http://api.openweathermap.org/data/2.5/weather?&q=camacha
# Processing Record 365 | Dharmadam
# http://api.openweathermap.org/data/2.5/weather?&q=dharmadam
# Processing Record 366 | Aswan
# http://api.openweathermap.org/data/2.5/weather?&q=aswan
# Processing Record 367 | Capuy
# http://api.openweathermap.org/data/2.5/weather?&q=capuy
# Processing Record 368 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?&q=egvekinot
# Processing Record 369 | Manado
# http://api.openweathermap.org/data/2.5/weather?&q=manado
# Processing Record 370 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?&q=labuhan
# Processing Record 371 | Voznesenye
# http://api.openweathermap.org/data/2.5/weather?&q=voznesenye
# Processing Record 372 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?&q=kungurtug
# Processing Record 373 | Togur
# http://api.openweathermap.org/data/2.5/weather?&q=togur
# Processing Record 374 | Bayir
# http://api.openweathermap.org/data/2.5/weather?&q=bayir
# Processing Record 375 | Puerto Leguizamo
# http://api.openweathermap.org/data/2.5/weather?&q=puerto leguizamo
# Processing Record 376 | Cururupu
# http://api.openweathermap.org/data/2.5/weather?&q=cururupu
# Processing Record 377 | Fallon
# http://api.openweathermap.org/data/2.5/weather?&q=fallon
# Processing Record 378 | Nizhniy Odes
# http://api.openweathermap.org/data/2.5/weather?&q=nizhniy odes
# Processing Record 379 | Latehar
# http://api.openweathermap.org/data/2.5/weather?&q=latehar
# Processing Record 380 | Muncar
# http://api.openweathermap.org/data/2.5/weather?&q=muncar
# City not found. Skipping...
# Processing Record 381 | Orocue
# http://api.openweathermap.org/data/2.5/weather?&q=orocue
# Processing Record 382 | Gweta
# http://api.openweathermap.org/data/2.5/weather?&q=gweta
# Processing Record 383 | La Romana
# http://api.openweathermap.org/data/2.5/weather?&q=la romana
# Processing Record 384 | Moba
# http://api.openweathermap.org/data/2.5/weather?&q=moba
# Processing Record 385 | Gorele
# http://api.openweathermap.org/data/2.5/weather?&q=gorele
# Processing Record 386 | Alpena
# http://api.openweathermap.org/data/2.5/weather?&q=alpena
# Processing Record 387 | Pandharpur
# http://api.openweathermap.org/data/2.5/weather?&q=pandharpur
# Processing Record 388 | Safranbolu
# http://api.openweathermap.org/data/2.5/weather?&q=safranbolu
# Processing Record 389 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?&q=klaksvik
# Processing Record 390 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?&q=imbituba
# City not found. Skipping...
# Processing Record 391 | Abeche
# http://api.openweathermap.org/data/2.5/weather?&q=abeche
# Processing Record 392 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?&q=zyryanka
# Processing Record 393 | Margate
# http://api.openweathermap.org/data/2.5/weather?&q=margate
# Processing Record 394 | Energetik
# http://api.openweathermap.org/data/2.5/weather?&q=energetik
# Processing Record 395 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?&q=ponta delgada
# Processing Record 396 | Grafton
# http://api.openweathermap.org/data/2.5/weather?&q=grafton
# Processing Record 397 | Izumo
# http://api.openweathermap.org/data/2.5/weather?&q=izumo
# Processing Record 398 | Mtambile
# http://api.openweathermap.org/data/2.5/weather?&q=mtambile
# Processing Record 399 | Nador
# http://api.openweathermap.org/data/2.5/weather?&q=nador
# Processing Record 400 | Horsham
# http://api.openweathermap.org/data/2.5/weather?&q=horsham
# Processing Record 401 | Gat
# http://api.openweathermap.org/data/2.5/weather?&q=gat
# Processing Record 402 | Clarksdale
# http://api.openweathermap.org/data/2.5/weather?&q=clarksdale
# Processing Record 403 | Kawalu
# http://api.openweathermap.org/data/2.5/weather?&q=kawalu
# Processing Record 404 | Lamu
# http://api.openweathermap.org/data/2.5/weather?&q=lamu
# Processing Record 405 | Newport
# http://api.openweathermap.org/data/2.5/weather?&q=newport
# Processing Record 406 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?&q=baruun-urt
# Processing Record 407 | Falmouth
# http://api.openweathermap.org/data/2.5/weather?&q=falmouth
# Processing Record 408 | Angahuan
# http://api.openweathermap.org/data/2.5/weather?&q=angahuan
# Processing Record 409 | Betare Oya
# http://api.openweathermap.org/data/2.5/weather?&q=betare oya
# Processing Record 410 | Gimli
# http://api.openweathermap.org/data/2.5/weather?&q=gimli
# Processing Record 411 | Florian
# http://api.openweathermap.org/data/2.5/weather?&q=florian
# Processing Record 412 | Harper
# http://api.openweathermap.org/data/2.5/weather?&q=harper
# Processing Record 413 | Alghero
# http://api.openweathermap.org/data/2.5/weather?&q=alghero
# Processing Record 414 | Saint-Louis
# http://api.openweathermap.org/data/2.5/weather?&q=saint-louis
# Processing Record 415 | Sable-sur-Sarthe
# http://api.openweathermap.org/data/2.5/weather?&q=sable-sur-sarthe
# Processing Record 416 | Durango
# http://api.openweathermap.org/data/2.5/weather?&q=durango
# Processing Record 417 | Orlik
# http://api.openweathermap.org/data/2.5/weather?&q=orlik
# Processing Record 418 | Carballo
# http://api.openweathermap.org/data/2.5/weather?&q=carballo
# Processing Record 419 | Laguna
# http://api.openweathermap.org/data/2.5/weather?&q=laguna
# Processing Record 420 | Dom Pedrito
# http://api.openweathermap.org/data/2.5/weather?&q=dom pedrito
# Processing Record 421 | Homer
# http://api.openweathermap.org/data/2.5/weather?&q=homer
# Processing Record 422 | Bafra
# http://api.openweathermap.org/data/2.5/weather?&q=bafra
# Processing Record 423 | Junagarh
# http://api.openweathermap.org/data/2.5/weather?&q=junagarh
# Processing Record 424 | Seydi
# http://api.openweathermap.org/data/2.5/weather?&q=seydi
# Processing Record 425 | George Town
# http://api.openweathermap.org/data/2.5/weather?&q=george town
# Processing Record 426 | Levokumskoye
# http://api.openweathermap.org/data/2.5/weather?&q=levokumskoye
# City not found. Skipping...
# Processing Record 427 | Grants Pass
# http://api.openweathermap.org/data/2.5/weather?&q=grants pass
# Processing Record 428 | Manicore
# http://api.openweathermap.org/data/2.5/weather?&q=manicore
# Processing Record 429 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?&q=leshukonskoye
# Processing Record 430 | La Asuncion
# http://api.openweathermap.org/data/2.5/weather?&q=la asuncion
# Processing Record 431 | Oldenburg
# http://api.openweathermap.org/data/2.5/weather?&q=oldenburg
# City not found. Skipping...
# Processing Record 432 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?&q=alta floresta
# Processing Record 433 | Dakar
# http://api.openweathermap.org/data/2.5/weather?&q=dakar
# Processing Record 434 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?&q=boyolangu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 435 | Karaton
# http://api.openweathermap.org/data/2.5/weather?&q=karaton
# Processing Record 436 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?&q=maniitsoq
# Processing Record 437 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?&q=riyadh
# Processing Record 438 | Morondava
# http://api.openweathermap.org/data/2.5/weather?&q=morondava
# Processing Record 439 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?&q=deputatskiy
# Processing Record 440 | Salalah
# http://api.openweathermap.org/data/2.5/weather?&q=salalah
# Processing Record 441 | Dalby
# http://api.openweathermap.org/data/2.5/weather?&q=dalby
# Processing Record 442 | Keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?&q=keetmanshoop
# Processing Record 443 | Samarai
# http://api.openweathermap.org/data/2.5/weather?&q=samarai
# Processing Record 444 | Praia
# http://api.openweathermap.org/data/2.5/weather?&q=praia
# Processing Record 445 | Tautira
# http://api.openweathermap.org/data/2.5/weather?&q=tautira
# Processing Record 446 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?&q=hobyo
# Processing Record 447 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?&q=saint-joseph
# Processing Record 448 | Maldonado
# http://api.openweathermap.org/data/2.5/weather?&q=maldonado
# Processing Record 449 | Mumford
# http://api.openweathermap.org/data/2.5/weather?&q=mumford
# Processing Record 450 | Bara
# http://api.openweathermap.org/data/2.5/weather?&q=bara
# Processing Record 451 | Funadhoo
# http://api.openweathermap.org/data/2.5/weather?&q=funadhoo
# Processing Record 452 | Mikhaylovka
# http://api.openweathermap.org/data/2.5/weather?&q=mikhaylovka
# Processing Record 453 | Hauterive
# http://api.openweathermap.org/data/2.5/weather?&q=hauterive
# Processing Record 454 | Boguchany
# http://api.openweathermap.org/data/2.5/weather?&q=boguchany
# Processing Record 455 | Lengshuijiang
# http://api.openweathermap.org/data/2.5/weather?&q=lengshuijiang
# Processing Record 456 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?&q=whitehorse
# Processing Record 457 | Touros
# http://api.openweathermap.org/data/2.5/weather?&q=touros
# Processing Record 458 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?&q=takoradi
# Processing Record 459 | Ayagoz
# http://api.openweathermap.org/data/2.5/weather?&q=ayagoz
# Processing Record 460 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?&q=antalaha
# Processing Record 461 | Parrita
# http://api.openweathermap.org/data/2.5/weather?&q=parrita
# Processing Record 462 | Kautokeino
# http://api.openweathermap.org/data/2.5/weather?&q=kautokeino
# Processing Record 463 | Rosarito
# http://api.openweathermap.org/data/2.5/weather?&q=rosarito
# Processing Record 464 | Khash
# http://api.openweathermap.org/data/2.5/weather?&q=khash
# Processing Record 465 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?&q=grindavik
# Processing Record 466 | Tarakan
# http://api.openweathermap.org/data/2.5/weather?&q=tarakan
# Processing Record 467 | Westport
# http://api.openweathermap.org/data/2.5/weather?&q=westport
# Processing Record 468 | Tashtagol
# http://api.openweathermap.org/data/2.5/weather?&q=tashtagol
# Processing Record 469 | Pokhara
# http://api.openweathermap.org/data/2.5/weather?&q=pokhara
# Processing Record 470 | Kiama
# http://api.openweathermap.org/data/2.5/weather?&q=kiama
# Processing Record 471 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?&q=lagoa
# Processing Record 472 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?&q=beringovskiy
# Processing Record 473 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?&q=carutapera
# Processing Record 474 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?&q=marienburg
# Processing Record 475 | Linxia
# http://api.openweathermap.org/data/2.5/weather?&q=linxia
# Processing Record 476 | Kuybyshevskiy Zaton
# http://api.openweathermap.org/data/2.5/weather?&q=kuybyshevskiy zaton
# Processing Record 477 | Iralaya
# http://api.openweathermap.org/data/2.5/weather?&q=iralaya
# Processing Record 478 | Gunjur
# http://api.openweathermap.org/data/2.5/weather?&q=gunjur
# Processing Record 479 | Les Cayes
# http://api.openweathermap.org/data/2.5/weather?&q=les cayes
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 480 | Otaru
# http://api.openweathermap.org/data/2.5/weather?&q=otaru
# Processing Record 481 | Menongue
# http://api.openweathermap.org/data/2.5/weather?&q=menongue
# Processing Record 482 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?&q=havre-saint-pierre
# Processing Record 483 | Saint-Denis
# http://api.openweathermap.org/data/2.5/weather?&q=saint-denis
# Processing Record 484 | Brae
# http://api.openweathermap.org/data/2.5/weather?&q=brae
# Processing Record 485 | Eureka
# http://api.openweathermap.org/data/2.5/weather?&q=eureka
# City not found. Skipping...
# Processing Record 486 | Elizabeth City
# http://api.openweathermap.org/data/2.5/weather?&q=elizabeth city
# Processing Record 487 | Lulea
# http://api.openweathermap.org/data/2.5/weather?&q=lulea
# Processing Record 488 | Linhares
# http://api.openweathermap.org/data/2.5/weather?&q=linhares
# Processing Record 489 | Erice
# http://api.openweathermap.org/data/2.5/weather?&q=erice
# Processing Record 490 | Caruray
# http://api.openweathermap.org/data/2.5/weather?&q=caruray
# Processing Record 491 | Flinders
# http://api.openweathermap.org/data/2.5/weather?&q=flinders
# Processing Record 492 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?&q=henties bay
# Processing Record 493 | Kjopsvik
# http://api.openweathermap.org/data/2.5/weather?&q=kjopsvik
# Processing Record 494 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?&q=mount isa
# City not found. Skipping...
# Processing Record 495 | Zig
# http://api.openweathermap.org/data/2.5/weather?&q=zig
# Processing Record 496 | Coxim
# http://api.openweathermap.org/data/2.5/weather?&q=coxim
# City not found. Skipping...
# Processing Record 497 | Gualaceo
# http://api.openweathermap.org/data/2.5/weather?&q=gualaceo
# Processing Record 498 | Musson
# http://api.openweathermap.org/data/2.5/weather?&q=musson
# Processing Record 499 | Goderich
# http://api.openweathermap.org/data/2.5/weather?&q=goderich
# Processing Record 500 | Kanigoro
# http://api.openweathermap.org/data/2.5/weather?&q=kanigoro
# Processing Record 501 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?&q=san quintin
# Processing Record 502 | Devils Lake
# http://api.openweathermap.org/data/2.5/weather?&q=devils lake
# City not found. Skipping...
# Processing Record 503 | Makhachkala
# http://api.openweathermap.org/data/2.5/weather?&q=makhachkala
# Processing Record 504 | Singarayakonda
# http://api.openweathermap.org/data/2.5/weather?&q=singarayakonda
# Processing Record 505 | Marsabit
# http://api.openweathermap.org/data/2.5/weather?&q=marsabit
# Processing Record 506 | Bousse
# http://api.openweathermap.org/data/2.5/weather?&q=bousse
# Processing Record 507 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?&q=cockburn town
# City not found. Skipping...
# Processing Record 508 | Marquette
# http://api.openweathermap.org/data/2.5/weather?&q=marquette
# Processing Record 509 | Phimai
# http://api.openweathermap.org/data/2.5/weather?&q=phimai
# Processing Record 510 | Diego de Almagro
# http://api.openweathermap.org/data/2.5/weather?&q=diego de almagro
# Processing Record 511 | Nicolas Bravo
# http://api.openweathermap.org/data/2.5/weather?&q=nicolas bravo
# Processing Record 512 | Falam
# http://api.openweathermap.org/data/2.5/weather?&q=falam
# Processing Record 513 | Punta Alta
# http://api.openweathermap.org/data/2.5/weather?&q=punta alta
# Processing Record 514 | Abha
# http://api.openweathermap.org/data/2.5/weather?&q=abha
# Processing Record 515 | Maumere
# http://api.openweathermap.org/data/2.5/weather?&q=maumere
# Processing Record 516 | Koslan
# http://api.openweathermap.org/data/2.5/weather?&q=koslan
# Processing Record 517 | Sendhwa
# http://api.openweathermap.org/data/2.5/weather?&q=sendhwa
# Processing Record 518 | Galesong
# http://api.openweathermap.org/data/2.5/weather?&q=galesong
# Processing Record 519 | Kukushtan
# http://api.openweathermap.org/data/2.5/weather?&q=kukushtan
# Processing Record 520 | Hami
# http://api.openweathermap.org/data/2.5/weather?&q=hami
# Processing Record 521 | Mizdah
# http://api.openweathermap.org/data/2.5/weather?&q=mizdah
# Processing Record 522 | Yaan
# http://api.openweathermap.org/data/2.5/weather?&q=yaan
# Processing Record 523 | Awbari
# http://api.openweathermap.org/data/2.5/weather?&q=awbari
# City not found. Skipping...
# Processing Record 524 | Kurchum
# http://api.openweathermap.org/data/2.5/weather?&q=kurchum
# Processing Record 525 | Bud
# http://api.openweathermap.org/data/2.5/weather?&q=bud
# Processing Record 526 | Pavlodar
# http://api.openweathermap.org/data/2.5/weather?&q=pavlodar
# Processing Record 527 | Itarema
# http://api.openweathermap.org/data/2.5/weather?&q=itarema
# Processing Record 528 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?&q=guerrero negro
# Processing Record 529 | Tezu
# http://api.openweathermap.org/data/2.5/weather?&q=tezu
# Processing Record 530 | Bima
# http://api.openweathermap.org/data/2.5/weather?&q=bima
# Processing Record 531 | Baykit
# http://api.openweathermap.org/data/2.5/weather?&q=baykit
# Processing Record 532 | Rio Verde de Mato Grosso
# http://api.openweathermap.org/data/2.5/weather?&q=rio verde de mato grosso
# Processing Record 533 | Minna
# http://api.openweathermap.org/data/2.5/weather?&q=minna
# Processing Record 534 | Morden
# http://api.openweathermap.org/data/2.5/weather?&q=morden
# Processing Record 535 | Kargasok
# http://api.openweathermap.org/data/2.5/weather?&q=kargasok
# Processing Record 536 | Chapais
# http://api.openweathermap.org/data/2.5/weather?&q=chapais
# Processing Record 537 | Mana
# http://api.openweathermap.org/data/2.5/weather?&q=mana

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          537
# Cloudiness    537
# Country       537
# Date          537
# Humidity      537
# Lat           537
# Lng           537
# Max Temp      537
# Wind Speed    537
# dtype: int64

# %%
 # Save data frame to CSV
weather_data.to_csv("weather_data.csv")

# Display data frame head 
weather_data.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Atuona          30      PF  1562977461        71  -9.80 -139.03
# 1  Busselton          95      AU  1562977461        85 -33.64  115.35
# 2     Bulgan          76      MN  1562977462        78  48.81  103.53
# 3     Faanui          33      PF  1562977462        70 -16.48 -151.75
# 4      Gamba          99      CN  1562977462        76  28.28   88.52
#
#    Max Temp  Wind Speed
# 0     27.15        6.90
# 1      9.44        6.26
# 2     17.15        0.97
# 3     25.15        0.77
# 4      5.35        1.08

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

# Save the figure
plt.savefig("output_data\Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data\Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data\Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolor="black", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data\Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
